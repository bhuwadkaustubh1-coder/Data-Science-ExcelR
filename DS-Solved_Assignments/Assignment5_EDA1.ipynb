# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

sns.set_style("whitegrid")

# %%
file_path = r"C:\Users\Admin\OneDrive\Desktop\Data Science ExcelR\Assignments\Assignment 5\Cardiotocographic.csv"
df = pd.read_csv(file_path)

df.head()
# Out:
#            LB        AC   FM        UC        DL   DS   DP  ASTV  MSTV  ALTV  \
# 0  120.000000  0.000000  0.0  0.000000  0.000000  0.0  0.0  73.0   0.5  43.0
# 1  132.000000  0.006380  0.0  0.006380  0.003190  0.0  0.0  17.0   2.1   0.0
# 2  133.000000  0.003322  0.0  0.008306  0.003322  0.0  0.0  16.0   2.1   0.0
# 3  134.000000  0.002561  0.0  0.007742  0.002561  0.0  0.0  16.0   2.4   0.0
# 4  131.948232  0.006515  0.0  0.008143  0.000000  0.0  0.0  16.0   2.4   0.0
#
#    MLTV  Width  Tendency  NSP
# 0   2.4   64.0  0.999926  2.0
# 1  10.4  130.0  0.000000  1.0
# 2  13.4  130.0  0.000000  1.0
# 3  23.0  117.0  1.000000  1.0
# 4  19.9  117.0  1.000000  1.0

# %%
print("Number of Rows:", df.shape[0])
print("Number of Columns:", df.shape[1])
print("Column Names:")
print(df.columns.tolist())
df.info()
# Out:
# Number of Rows: 2126
# Number of Columns: 14
# Column Names:
# ['LB', 'AC', 'FM', 'UC', 'DL', 'DS', 'DP', 'ASTV', 'MSTV', 'ALTV', 'MLTV', 'Width', 'Tendency', 'NSP']
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   LB        2105 non-null   float64
#  1   AC        2106 non-null   float64
#  2   FM        2126 non-null   float64
#  3   UC        2126 non-null   float64
#  4   DL        2126 non-null   float64
#  5   DS        2105 non-null   float64
#  6   DP        2105 non-null   float64
#  7   ASTV      2126 non-null   float64
#  8   MSTV      2126 non-null   float64
#  9   ALTV      2126 non-null   float64
#  10  MLTV      2105 non-null   float64
#  11  Width     2105 non-null   float64
#  12  Tendency  2105 non-null   float64
#  13  NSP       2105 non-null   float64
# dtypes: float64(14)
# memory usage: 232.7 KB

# %%
print("First 5 Records:")
display(df.head())

print("\nLast 5 Records:")
display(df.tail())
# Out:
# First 5 Records:
#            LB        AC   FM        UC        DL   DS   DP  ASTV  MSTV  ALTV  \
# 0  120.000000  0.000000  0.0  0.000000  0.000000  0.0  0.0  73.0   0.5  43.0
# 1  132.000000  0.006380  0.0  0.006380  0.003190  0.0  0.0  17.0   2.1   0.0
# 2  133.000000  0.003322  0.0  0.008306  0.003322  0.0  0.0  16.0   2.1   0.0
# 3  134.000000  0.002561  0.0  0.007742  0.002561  0.0  0.0  16.0   2.4   0.0
# 4  131.948232  0.006515  0.0  0.008143  0.000000  0.0  0.0  16.0   2.4   0.0
#
#    MLTV  Width  Tendency  NSP
# 0   2.4   64.0  0.999926  2.0
# 1  10.4  130.0  0.000000  1.0
# 2  13.4  130.0  0.000000  1.0
# 3  23.0  117.0  1.000000  1.0
# 4  19.9  117.0  1.000000  1.0
# Last 5 Records:
#          LB        AC        FM        UC   DL   DS   DP  ASTV  MSTV  \
# 2121  140.0  0.000000  0.961268  0.007426  0.0  0.0  0.0  79.0   0.2
# 2122  140.0  0.000775  0.000000  0.006979  0.0  0.0  0.0  78.0   0.4
# 2123  140.0  0.000980  0.000000  0.006863  0.0  0.0  0.0  79.0   0.4
# ...

# %%
print(df.dtypes)
# Out:
# LB          float64
# AC          float64
# FM          float64
# UC          float64
# DL          float64
# DS          float64
# DP          float64
# ASTV        float64
# MSTV        float64
# ALTV        float64
# MLTV        float64
# Width       float64
# Tendency    float64
# NSP         float64
# dtype: object

# %%
object_columns = df.select_dtypes(include='object').columns

print("Object/String Columns:")
print(object_columns.tolist())
# Out:
# Object/String Columns:
# []

# %%
for column in df.columns:
    df[column] = pd.to_numeric(df[column], errors='coerce')

print(df.dtypes)
# Out:
# LB          float64
# AC          float64
# FM          float64
# UC          float64
# DL          float64
# DS          float64
# DP          float64
# ASTV        float64
# MSTV        float64
# ALTV        float64
# MLTV        float64
# Width       float64
# Tendency    float64
# NSP         float64
# dtype: object

# %%
#Check Missing Values

missing_values = df.isnull().sum()

print("Missing Values:")
print(missing_values)
# Out:
# Missing Values:
# LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %%
missing_percentage = (df.isnull().sum() / len(df)) * 100

missing_summary = pd.DataFrame({
    'Missing Values': df.isnull().sum(),
    'Percentage Missing': missing_percentage
})

missing_summary
# Out:
#           Missing Values  Percentage Missing
# LB                    21            0.987770
# AC                    20            0.940734
# FM                     0            0.000000
# UC                     0            0.000000
# DL                     0            0.000000
# DS                    21            0.987770
# DP                    21            0.987770
# ASTV                   0            0.000000
# MSTV                   0            0.000000
# ALTV                   0            0.000000
# MLTV                  21            0.987770
# Width                 21            0.987770
# Tendency              21            0.987770
# NSP                   21            0.987770

# %%
for column in df.columns:
    if df[column].isnull().sum() > 0:
        df[column] = df[column].fillna(df[column].median())

print("Missing values after imputation:")
print(df.isnull().sum())

print("Total Missing Values:", df.isnull().sum().sum())
# Out:
# Missing values after imputation:
# LB          0
# AC          0
# FM          0
# UC          0
# DL          0
# DS          0
# DP          0
# ASTV        0
# MSTV        0
# ALTV        0
# MLTV        0
# Width       0
# Tendency    0
# NSP         0
# dtype: int64
# Total Missing Values: 0

# %%
#Check Duplicate Records

duplicate_count = df.duplicated().sum()

print("Number of Duplicate Records:", duplicate_count)
# Out:
# Number of Duplicate Records: 2

# %%
df = df.drop_duplicates()

print("Dataset Shape After Removing Duplicates:", df.shape)
# Out:
# Dataset Shape After Removing Duplicates: (2124, 14)

# %%
df.describe()
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2124.000000  2124.000000  2124.000000  2124.000000  2124.000000
# mean    133.338641     0.003205     0.009904     0.004394     0.001897
# std      11.212447     0.004374     0.067571     0.003340     0.003344
# min      51.842487    -0.019284    -0.480634    -0.014925    -0.015393
# 25%     126.000000     0.000000     0.000000     0.001858     0.000000
# 50%     133.000000     0.001634     0.000000     0.004486     0.000000
# 75%     140.000000     0.005612     0.002568     0.006536     0.003292
# max     214.000000     0.038567     0.961268     0.030002     0.030769
#
#                 DS           DP         ASTV         MSTV         ALTV  \
# count  2124.000000  2124.000000  2124.000000  2124.000000  2124.000000
# mean      0.000002     0.000174    47.012459     1.364345    10.295650
# std       0.000141     0.000836    18.812403     1.174084    21.212676
# ...

# %%
skewness = df.skew().sort_values(ascending=False)

print("Skewness of Variables:")
display(skewness)
# Out:
# Skewness of Variables:
# DS          8.457283
# FM          6.749691
# DP          6.453124
# MSTV        4.141709
# MLTV        3.563587
# ALTV        2.979526
# AC          2.032003
# DL          2.008927
# NSP         1.825387
# UC          0.973685
# Width       0.498480
# LB          0.323569
# ASTV        0.054887
# Tendency   -0.485275
# dtype: float64

# %%
outlier_summary = []

for column in df.columns:
    
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    
    IQR = Q3 - Q1
    
    lower_limit = Q1 - 1.5 * IQR
    upper_limit = Q3 + 1.5 * IQR
    
    outliers = df[
        (df[column] < lower_limit) |
        (df[column] > upper_limit)
    ]
    
    outlier_summary.append({
        'Column': column,
        'Q1': Q1,
        'Q3': Q3,
        'IQR': IQR,
        'Lower Limit': lower_limit,
        'Upper Limit': upper_limit,
        'Number of Outliers': len(outliers)
    })

outlier_df = pd.DataFrame(outlier_summary)

outlier_df
# Out:
#       Column          Q1          Q3        IQR  Lower Limit  Upper Limit  \
# 0         LB  126.000000  140.000000  14.000000   105.000000   161.000000
# 1         AC    0.000000    0.005612   0.005612    -0.008418     0.014030
# 2         FM    0.000000    0.002568   0.002568    -0.003853     0.006421
# 3         UC    0.001858    0.006536   0.004678    -0.005158     0.013552
# 4         DL    0.000000    0.003292   0.003292    -0.004938     0.008230
# 5         DS    0.000000    0.000000   0.000000     0.000000     0.000000
# 6         DP    0.000000    0.000000   0.000000     0.000000     0.000000
# 7       ASTV   32.000000   61.000000  29.000000   -11.500000   104.500000
# 8       MSTV    0.700000    1.700000   1.000000    -0.800000     3.200000
# 9       ALTV    0.000000   11.000000  11.000000   -16.500000    27.500000
# 10      MLTV    4.600000   10.800000   6.200000    -4.700000    20.100000
# 11     Width   37.000000  100.000000  63.000000   -57.500000   194.500000
# ...

# %%
for column in df.columns:
    
    plt.figure(figsize=(8, 5))
    
    plt.hist(
        df[column],
        bins=30,
        edgecolor='black'
    )
    
    plt.title(f'Distribution of {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    
    plt.tight_layout()
    plt.show()

# %%
print("NSP Value Counts:")
print(df['NSP'].value_counts().sort_index())

plt.figure(figsize=(8, 5))

sns.countplot(
    x='NSP',
    data=df
)

plt.title('Distribution of NSP Classes')
plt.xlabel('NSP Class')
plt.ylabel('Number of Records')

plt.show()
# Out:
# NSP Value Counts:
# NSP
# -1.025988    1
# -1.000000    5
#  0.967075    1
#  0.969447    1
#  0.972305    1
#             ..
#  3.015185    1
#  3.019152    1
#  3.020038    1
#  3.034545    1
#  5.000000    4
# Name: count, Length: 111, dtype: int64

# %%
nsp_percentage = df['NSP'].value_counts(normalize=True).sort_index() * 100

print("NSP Percentage Distribution:")
print(nsp_percentage)
# Out:
# NSP Percentage Distribution:
# NSP
# -1.025988    0.047081
# -1.000000    0.235405
#  0.967075    0.047081
#  0.969447    0.047081
#  0.972305    0.047081
#                ...
#  3.015185    0.047081
#  3.019152    0.047081
#  3.020038    0.047081
#  3.034545    0.047081
#  5.000000    0.188324
# Name: proportion, Length: 111, dtype: float64

# %%
plt.figure(figsize=(14, 10))

sns.heatmap(
    correlation_matrix,
    annot=True,
    fmt='.2f',
    cmap='coolwarm',
    linewidths=0.5
)

plt.title('Correlation Heatmap')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 5))

sns.scatterplot(
    data=df,
    x='LB',
    y='ASTV',
    hue='NSP'
)

plt.title('Baseline Heart Rate vs Abnormal Short-Term Variability')
plt.xlabel('LB')
plt.ylabel('ASTV')

plt.show()

# %%
plt.figure(figsize=(8, 5))

sns.scatterplot(
    data=df,
    x='LB',
    y='MSTV',
    hue='NSP'
)

plt.title('Baseline Heart Rate vs Mean Short-Term Variability')
plt.xlabel('LB')
plt.ylabel('MSTV')

plt.show()

# %%
plt.figure(figsize=(8, 5))

sns.scatterplot(
    data=df,
    x='ASTV',
    y='ALTV',
    hue='NSP'
)

plt.title('Short-Term vs Long-Term Abnormal Variability')
plt.xlabel('ASTV')
plt.ylabel('ALTV')

plt.show()

# %%
#The Exploratory Data Analysis of the Cardiotocographic dataset provided a comprehensive understanding of the dataset's structure, distributions, relationships, and data quality. The dataset contains 2,126 observations and 14 numerical variables related to fetal heart rate, fetal movements, uterine contractions, decelerations, and heart-rate variability.
#During data preparation, missing values were identified and handled using median imputation. Duplicate records and data types were also examined. Statistical analysis using mean, median, standard deviation, and interquartile range helped understand the central tendency and variability of each variable.
#Histograms and boxplots showed that several variables have skewed distributions and potential outliers. These outliers should be investigated carefully because extreme values in medical datasets may represent genuine clinical observations rather than data-entry errors.
#The correlation heatmap and scatter plots helped identify relationships between fetal heart-rate characteristics and other variables. The analysis of the NSP variable also showed how observations are distributed across different fetal status classes. Pair plots and violin plots provided additional insights into how selected variables vary across NSP categories.
#Overall, the EDA provides a strong foundation for further analysis. The identified relationships, distributions, missing values, and potential outliers can be considered before applying statistical modeling or machine-learning techniques for fetal health classification.
